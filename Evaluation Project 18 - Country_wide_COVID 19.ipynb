# %% [markdown]
# # Country_wide_COVID 19 Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
ds1=pd.read_csv('Country_wide_COVID 19_Datasets.csv')
ds1
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-18                 Russia   145927292    1831892.0      36793.0
# 2     2020-04-18                  Spain    46752703     930230.0     194416.0
# 3     2020-04-18                 Brazil   212380932      62985.0      36722.0
# 4     2020-04-18                     UK    67844241     460437.0     114217.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-18              St. Barth        9874          NaN          6.0
# 6599  2020-05-18         Western Sahara      595462          NaN          6.0
# 6600  2020-05-18               Anguilla       14987          NaN          3.0
# 6601  2020-05-18                Lesotho     2140235          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
ds2=pd.read_csv('Country_wide_COVID 19_Datasets_Age')
ds2
# Out:
#                    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0                      USA                    0.189                     0.657
# 1                   Russia                    0.176                     0.682
# 2                    Spain                    0.147                     0.659
# 3                   Brazil                    0.217                     0.697
# 4                       UK                    0.177                     0.638
# ..                     ...                      ...                       ...
# 208              St. Barth                      NaN                       NaN
# 209         Western Sahara                      NaN                       NaN
# 210               Anguilla                      NaN                       NaN
# 211                Lesotho                    0.354                     0.601
# 212  Saint Pierre Miquelon                      NaN                       NaN
#
#      Fraction age 65+ years
# ...

# %% [markdown]
# # Analyzing Country_wide_COVID 19_Dataset

# %%
df1=pd.DataFrame(ds1)
df1
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-18                 Russia   145927292    1831892.0      36793.0
# 2     2020-04-18                  Spain    46752703     930230.0     194416.0
# 3     2020-04-18                 Brazil   212380932      62985.0      36722.0
# 4     2020-04-18                     UK    67844241     460437.0     114217.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-18              St. Barth        9874          NaN          6.0
# 6599  2020-05-18         Western Sahara      595462          NaN          6.0
# 6600  2020-05-18               Anguilla       14987          NaN          3.0
# 6601  2020-05-18                Lesotho     2140235          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
df1.shape
# Out:
# (6603, 9)

# %%
df1.dtypes
# Out:
# Date                    object
# Country                 object
# Population               int64
# Total Tests            float64
# Total Cases            float64
# Total Deaths           float64
# Total Recovered        float64
# Serious or Critical    float64
# Active Cases           float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Date', 'Country', 'Population', 'Total Tests', 'Total Cases',
#        'Total Deaths', 'Total Recovered', 'Serious or Critical',
#        'Active Cases'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# Date                      0
# Country                   0
# Population                0
# Total Tests            1098
# Total Cases              49
# Total Deaths           1236
# Total Recovered         285
# Serious or Critical    2486
# Active Cases             59
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#Coutry vs Total Deaths

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Total Deaths', data=df1)
plt.title('Coutry wise Number of Total Deaths', fontsize=30)
plt.show()

# %%
#Coutry vs Population

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Population', data=df1)
plt.title('Coutry wise Total Population', fontsize=30)
plt.show()

# %%
#Coutry vs Total Tests

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Total Tests', data=df1)
plt.title('Coutry wise Total Tests', fontsize=30)
plt.show()

# %%
#Coutry vs Total Cases

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Total Cases', data=df1)
plt.title('Coutry wise Total Cases', fontsize=30)
plt.show()

# %%
#Coutry vs Total Recovered

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Total Recovered', data=df1)
plt.title('Coutry wise Total Recovered', fontsize=30)
plt.show()

# %%
#Coutry vs Total Recovered

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Total Recovered', data=df1)
plt.title('Coutry wise Total Recovered', fontsize=30)
plt.show()

# %%
#Coutry vs Serious or Critical

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Serious or Critical', data=df1)
plt.title('Coutry wise Serious or Critical', fontsize=30)
plt.show()

# %%
#Coutry vs Active Cases

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Active Cases', data=df1)
plt.title('Coutry wise Active Cases', fontsize=30)
plt.show()

# %%
#Seeing the null values with the help of heat map

plt.figure(figsize=(14, 10))
sns.heatmap(df1.isnull(),yticklabels=False, cbar=False)

# %%
#Finding the mean and median of population. As there is huge difference between the mean and median, it is easily understandable that filling the null values with mean and median will not result in inaccurate numbers.  
#So Replacing null values with Imputer

print(df1['Population'].mean())
print(df1['Population'].median())
# Out:
# 36379130.11737089
# 6859926.0

# %%
df1.columns
# Out:
# Index(['Date', 'Country', 'Population', 'Total Tests', 'Total Cases',
#        'Total Deaths', 'Total Recovered', 'Serious or Critical',
#        'Active Cases'],
#       dtype='object')

# %%
# Now lets replace the categorical values (alphabetic values) to numeric values using Label Encoder
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Lets Encode labels in columns 
df1['Country']= label_encoder.fit_transform(df1['Country'])

# %%
df1.isnull().sum()
# Out:
# Date                      0
# Country                   0
# Population                0
# Total Tests            1098
# Total Cases              49
# Total Deaths           1236
# Total Recovered         285
# Serious or Critical    2486
# Active Cases             59
# dtype: int64

# %%
#Printing the object data type columns and their unique values

for column in df1.columns:
    if df1[column].dtypes==object:
        print(str(column)+ ' : ' +str(df1[column].unique()))
        print(df1[column].value_counts())
        print('***************************************************************************')
        print('\n')
# Out:
# Date : ['2020-04-18' '2020-04-19' '2020-04-20' '2020-04-21' '2020-04-22'
#  '2020-04-23' '2020-04-24' '2020-04-25' '2020-04-26' '2020-04-27'
#  '2020-04-28' '2020-04-29' '2020-04-30' '2020-05-01' '2020-05-02'
#  '2020-05-03' '2020-05-04' '2020-05-05' '2020-05-06' '2020-05-07'
#  '2020-05-08' '2020-05-09' '2020-05-10' '2020-05-11' '2020-05-12'
#  '2020-05-13' '2020-05-14' '2020-05-15' '2020-05-16' '2020-05-17'
#  '2020-05-18']
# 2020-05-05    213
# 2020-05-15    213
# 2020-04-18    213
# 2020-04-30    213
# 2020-05-10    213
# 2020-04-26    213
# 2020-05-13    213
# 2020-05-03    213
# 2020-05-06    213
# 2020-04-20    213
# 2020-04-24    213
# 2020-04-22    213
# 2020-05-17    213
# 2020-05-02    213
# 2020-04-29    213
# 2020-05-11    213
# 2020-04-25    213
# 2020-04-21    213
# 2020-05-18    213
# 2020-05-07    213
# 2020-05-09    213
# 2020-04-23    213
# 2020-05-16    213
# 2020-04-19    213
# 2020-04-28    213
# 2020-05-08    213
# 2020-05-04    213
# 2020-05-14    213
# ...

# %%
# changing the Date column into actual date format

df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1.dtypes
# Out:
# Date                   datetime64[ns]
# Country                         int32
# Population                      int64
# Total Tests                   float64
# Total Cases                   float64
# Total Deaths                  float64
# Total Recovered               float64
# Serious or Critical           float64
# Active Cases                  float64
# dtype: object

# %%
#Splitting date/month/year format

df1["day"]=df1["Date"].dt.day
df1["month"]=df1["Date"].dt.month
df1["year"]=df1["Date"].dt.year
df1.head()
# Out:
#         Date  Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0 2020-04-18      201   330774664    3722145.0     738792.0       39014.0
# 1 2020-04-18      158   145927292    1831892.0      36793.0         313.0
# 2 2020-04-18      180    46752703     930230.0     194416.0       20043.0
# 3 2020-04-18       26   212380932      62985.0      36722.0        2361.0
# 4 2020-04-18      200    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases  day  month  year
# 0          68269.0              13551.0      631509.0   18      4  2020
# 1           3057.0                  8.0       33423.0   18      4  2020
# 2          74797.0               7371.0       99576.0   18      4  2020
# 3          14026.0               6634.0       20335.0   18      4  2020
# 4              NaN               1559.0       98409.0   18      4  2020

# %%
#As we have added date/month/year column to the dataset we can drop the "Date" column.

df1=df1.drop(['Date'], axis=1)
df1.head()
# Out:
#    Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0      201   330774664    3722145.0     738792.0       39014.0
# 1      158   145927292    1831892.0      36793.0         313.0
# 2      180    46752703     930230.0     194416.0       20043.0
# 3       26   212380932      62985.0      36722.0        2361.0
# 4      200    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases  day  month  year
# 0          68269.0              13551.0      631509.0   18      4  2020
# 1           3057.0                  8.0       33423.0   18      4  2020
# 2          74797.0               7371.0       99576.0   18      4  2020
# 3          14026.0               6634.0       20335.0   18      4  2020
# 4              NaN               1559.0       98409.0   18      4  2020

# %%
# Replacing null values with Imputer

from sklearn.impute import KNNImputer
x=df1
imputer = KNNImputer(n_neighbors=4)
x = imputer.fit_transform(x.values)
x = pd.DataFrame(x, columns=df1.columns)
x.head()
# Out:
#    Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0    201.0  330774664.0    3722145.0     738792.0       39014.0
# 1    158.0  145927292.0    1831892.0      36793.0         313.0
# 2    180.0   46752703.0     930230.0     194416.0       20043.0
# 3     26.0  212380932.0      62985.0      36722.0        2361.0
# 4    200.0   67844241.0     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases   day  month    year
# 0          68269.0              13551.0      631509.0  18.0    4.0  2020.0
# 1           3057.0                  8.0       33423.0  18.0    4.0  2020.0
# 2          74797.0               7371.0       99576.0  18.0    4.0  2020.0
# 3          14026.0               6634.0       20335.0  18.0    4.0  2020.0
# 4           2855.5               1559.0       98409.0  18.0    4.0  2020.0

# %%
df1=x

# %%
df1.head()
# Out:
#    Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0    201.0  330774664.0    3722145.0     738792.0       39014.0
# 1    158.0  145927292.0    1831892.0      36793.0         313.0
# 2    180.0   46752703.0     930230.0     194416.0       20043.0
# 3     26.0  212380932.0      62985.0      36722.0        2361.0
# 4    200.0   67844241.0     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases   day  month    year
# 0          68269.0              13551.0      631509.0  18.0    4.0  2020.0
# 1           3057.0                  8.0       33423.0  18.0    4.0  2020.0
# 2          74797.0               7371.0       99576.0  18.0    4.0  2020.0
# 3          14026.0               6634.0       20335.0  18.0    4.0  2020.0
# 4           2855.5               1559.0       98409.0  18.0    4.0  2020.0

# %%
#seeing null value with heatmap

plt.figure(figsize=(14, 10))
sns.heatmap(df1.isnull(),yticklabels=False, cbar=False, cmap='cool')

# %%
#Checking the summary of the dataset

df1.describe()
# Out:
#            Country    Population   Total Tests   Total Cases  Total Deaths  \
# count  6603.000000  6.603000e+03  6.603000e+03  6.603000e+03   6603.000000
# mean    106.000000  3.637913e+07  1.963658e+05  1.680636e+04   1155.765713
# std      61.491783  1.411537e+08  7.097661e+05  8.829674e+04   6015.620046
# min       0.000000  8.010000e+02  1.000000e+01  1.000000e+00      0.000000
# 25%      53.000000  8.672680e+05  2.172000e+03  7.600000e+01      3.500000
# 50%     106.000000  6.859926e+06  1.732900e+04  6.060000e+02     16.000000
# 75%     159.000000  2.546422e+07  1.177948e+05  4.757000e+03    121.000000
# max     212.000000  1.439324e+09  1.230074e+07  1.550294e+06  91981.000000
#
#        Total Recovered  Serious or Critical  Active Cases          day  \
# count      6603.000000          6603.000000  6.603000e+03  6603.000000
# mean       5667.999697           260.149250  1.005074e+04    15.580645
# std       23032.763683          1326.129653  6.531889e+04     8.526788
# ...

# %%
#To check correlation

df_cor=df1.corr()
df_cor
# Out:
#                           Country    Population  Total Tests  Total Cases  \
# Country              1.000000e+00 -2.867433e-02     0.118611     0.117414
# Population          -2.867433e-02  1.000000e+00     0.349848     0.226140
# Total Tests          1.186110e-01  3.498475e-01     1.000000     0.892465
# Total Cases          1.174135e-01  2.261400e-01     0.892465     1.000000
# Total Deaths         1.062453e-01  1.850009e-01     0.805458     0.935228
# Total Recovered      6.293045e-02  3.106347e-01     0.828520     0.823194
# Serious or Critical  6.829833e-02  1.767881e-01     0.731196     0.887614
# Active Cases         1.280912e-01  1.794889e-01     0.842778     0.977856
# day                  5.829489e-19  6.038413e-18    -0.035330    -0.017426
# month                2.163457e-18 -4.746909e-18     0.069862     0.034563
# year                          NaN           NaN          NaN          NaN
#
#                      Total Deaths  Total Recovered  Serious or Critical  \
# ...

# %%
#Heatmap

plt.figure(figsize=(14, 10))
sns.heatmap(df_cor, annot=True, fmt='.0%', cmap='BuPu')
plt.show()

# %% [raw]
# The year column is not contributing well in the dataset as it is same across the columns and it is not correlated to any of the other columns. Considering it's nil contribution towards the model building, we can drop the "year" column for further analysis.

# %%
#Dropping the 'year' column from the datset

df1=df1.drop(['year'], axis=1)
df1.head()
# Out:
#    Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0    201.0  330774664.0    3722145.0     738792.0       39014.0
# 1    158.0  145927292.0    1831892.0      36793.0         313.0
# 2    180.0   46752703.0     930230.0     194416.0       20043.0
# 3     26.0  212380932.0      62985.0      36722.0        2361.0
# 4    200.0   67844241.0     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases   day  month
# 0          68269.0              13551.0      631509.0  18.0    4.0
# 1           3057.0                  8.0       33423.0  18.0    4.0
# 2          74797.0               7371.0       99576.0  18.0    4.0
# 3          14026.0               6634.0       20335.0  18.0    4.0
# 4           2855.5               1559.0       98409.0  18.0    4.0

# %%
#Now lets check the Correlation factor with visualization after dropping year column

df_cor=df1.corr()
plt.figure(figsize=(12,8))
sns.heatmap(df_cor, cmap='YlGnBu', annot=True)

# %% [markdown]
# # Correlation with target column i.e. is Total Deaths

# %%
#Correlation with target column
plt.figure(figsize=(12, 6))
df1.drop('Total Deaths', axis=1).corrwith(df1['Total Deaths']).plot(kind='bar', grid=True)
plt.xticks(rotation='vertical')
plt.title("Correlation with target variable")
# Out:
# Text(0.5, 1.0, 'Correlation with target variable')

# %%
df1.hist(figsize=(25, 25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D7D3139C08>,
# ...
#       dtype=object)

# %%
sns.pairplot(df1)

# %% [markdown]
# # Checking the skewness

# %%
collist=df1.columns.values
ncol=3
nrow=5

plt.figure(figsize=(14, 14))
for i in range(0, len(collist)):
    plt.subplot(nrow, ncol, i+1)
    sns.distplot(df1[collist[i]], color='red')
    plt.tight_layout()

# %%
df1.skew()
# Out:
# Country                 0.000000
# Population              8.743503
# Total Tests             8.878372
# Total Cases            12.079390
# Total Deaths            8.970148
# Total Recovered         7.182600
# Serious or Critical     9.143801
# Active Cases           13.191156
# day                    -0.027570
# month                  -0.326934
# dtype: float64

# %%
#reating the skewness

import numpy as np
for index in df1.skew().index:
    if df1.skew().loc[index]>0.5:
        df1[index]=np.cbrt(df1[index])
    if df1.skew().loc[index]<-0.5:
        df1[index]=np.cbrt(df1[index])

# %%
df1.skew()
# Out:
# Country                0.000000
# Population             2.006228
# Total Tests            1.924128
# Total Cases            2.711374
# Total Deaths           3.321884
# Total Recovered        2.568899
# Serious or Critical    3.243211
# Active Cases           3.104102
# day                   -0.027570
# month                 -0.326934
# dtype: float64

# %% [markdown]
# # Plotting Outliers

# %%
plt.figure(figsize=(6, 20))
for i in range(0, len(collist)):
    plt.subplot(nrow, ncol, i+1)
    sns.boxplot(df1[collist[i]], color='purple', orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[1.54503887, 2.8985063 , 3.92700227, ..., 6.50130734, 0.28375725,
#         1.17669681],
#        [0.84570549, 1.89233317, 2.85776936, ..., 1.89695067, 0.28375725,
#         1.17669681],
#        [1.20350397, 0.8793258 , 2.04676733, ..., 3.11185914, 0.28375725,
#         1.17669681],
#        ...,
#        [1.64262028, 1.16581232, 1.04498323, ..., 0.87100389, 0.28375725,
#         0.84983659],
#        [0.06505427, 0.53071285, 0.40463348, ..., 0.78507409, 0.28375725,
#         0.84983659],
#        [0.95955046, 1.20658835, 1.04498323, ..., 0.87100389, 0.28375725,
#         0.84983659]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   0,    0,    0, ..., 6402, 6402, 6402], dtype=int64), array([2, 3, 4, ..., 1, 2, 5], dtype=int64))

# %%
df_new=df1[(z<3).all(axis=1)]

# %%
print(df1.shape, '\t', df_new.shape)
# Out:
# (6603, 10) 	 (6247, 10)

# %%
df=df_new
print(df.shape)
# Out:
# (6247, 10)

# %% [markdown]
# # Model Training

# %%
df.head()
# Out:
#     Country  Population  Total Tests  Total Cases  Total Deaths  \
# 1     158.0  526.476319   122.358259    33.259961      6.789661
# 8     197.0  438.351398    84.293240    43.502840     12.363856
# 11    152.0  320.480720    51.412394    24.340066      7.033850
# 13     36.0  335.318681    80.218983    32.198956     11.370314
# 14    168.0  326.317586    53.132928    20.225775      4.514357
#
#     Total Recovered  Serious or Critical  Active Cases   day  month
# 1         14.513266             2.000000     32.211811  18.0    4.0
# 8         21.864874            12.372572     41.210105  18.0    4.0
# 11        18.837018             4.890973     19.476412  18.0    4.0
# 13        22.378439             8.227825     27.459886  18.0    4.0
# 14        10.994488             4.272659     18.994458  18.0    4.0

# %%
#splitting the data into input and output variable

df_x=df.drop(columns=['Total Deaths'], axis=1)
df_x.head()
# Out:
#     Country  Population  Total Tests  Total Cases  Total Recovered  \
# 1     158.0  526.476319   122.358259    33.259961        14.513266
# 8     197.0  438.351398    84.293240    43.502840        21.864874
# 11    152.0  320.480720    51.412394    24.340066        18.837018
# 13     36.0  335.318681    80.218983    32.198956        22.378439
# 14    168.0  326.317586    53.132928    20.225775        10.994488
#
#     Serious or Critical  Active Cases   day  month
# 1              2.000000     32.211811  18.0    4.0
# 8             12.372572     41.210105  18.0    4.0
# 11             4.890973     19.476412  18.0    4.0
# 13             8.227825     27.459886  18.0    4.0
# 14             4.272659     18.994458  18.0    4.0

# %%
y=df['Total Deaths']
y.head()
# Out:
# 1      6.789661
# 8     12.363856
# 11     7.033850
# 13    11.370314
# 14     4.514357
# Name: Total Deaths, dtype: float64

# %%
#Checking the shape of input and target variable

print(df_x.shape, '\t\t', y.shape)
# Out:
# (6247, 9) 		 (6247,)

# %%
#scaling in input variables

from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df_new=ss.fit_transform(df_x)
df_new
# Out:
# array([[ 0.8550598 ,  2.59091055,  4.17914212, ...,  3.16530849,
#          0.28181404, -1.17349599],
#        [ 1.4894801 ,  1.9020845 ,  2.44939506, ...,  4.35795024,
#          0.28181404, -1.17349599],
#        [ 0.75745668,  0.98075154,  0.9552267 , ...,  1.47734767,
#          0.28181404, -1.17349599],
#        ...,
#        [-1.63381981, -1.33156222, -1.23100466, ..., -1.10407298,
#          0.28181404,  0.85215459],
#        [ 0.07423483, -0.51696383, -0.34332704, ..., -0.97153211,
#          0.28181404,  0.85215459],
#        [ 0.96893011, -1.38386282, -1.23100466, ..., -1.10407298,
#          0.28181404,  0.85215459]])

# %%
x=pd.DataFrame(df_new, columns=df_x.columns)
x.head()
# Out:
#     Country  Population  Total Tests  Total Cases  Total Recovered  \
# 0  0.855060    2.590911     4.179142     2.649519         1.204715
# 1  1.489480    1.902085     2.449395     3.842440         2.428927
# 2  0.757457    0.980752     0.955227     1.610678         1.924720
# 3 -1.129537    1.096732     2.264253     2.525951         2.514448
# 4  1.017732    1.026375     1.033411     1.131513         0.618758
#
#    Serious or Critical  Active Cases       day     month
# 0            -0.349033      3.165308  0.281814 -1.173496
# 1             5.015432      4.357950  0.281814 -1.173496
# 2             1.146114      1.477348  0.281814 -1.173496
# 3             2.871861      2.535484  0.281814 -1.173496
# 4             0.826336      1.413469  0.281814 -1.173496

# %%
#Splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=.20, random_state=42)

# %%
#checking the shape

print(x_train.shape, '\t\t', x_test.shape)
# Out:
# (4997, 9) 		 (1250, 9)

# %%
#Checking the shape

print(y_train.shape, '\t\t', y_test.shape)
# Out:
# (4997,) 		 (1250,)

# %% [markdown]
# Using Regressor models mor model building

# %%
#importing library

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

#Importing error Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#Using algorithms via for loop

model=[LinearRegression(), RandomForestRegressor(), DecisionTreeRegressor(), KNeighborsRegressor(), SVR(), Lasso(), Ridge(), ElasticNet()]
for m in model:
    m.fit(x_train, y_train)
    print('Score of', m, 'is: ', m.score(x_train, y_train))
    predm=m.predict(x_test)
    print('\n')
    print('Error:')
    print('Mean absolute error:', mean_absolute_error(y_test, predm))
    print('Mean squared error:', mean_squared_error(y_test, predm))
    print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, predm)))
    print('r2_score:', r2_score(y_test, predm))
    print('\n')
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is:  0.8047871968084084
#
#
# Error:
# Mean absolute error: 0.9381573918231902
# Mean squared error: 2.094477179892383
# Root mean squared error: 1.447230866134489
# r2_score: 0.783503805251424
#
#
# *******************************************************************************************************
#
#
# Score of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) is:  0.9982893367116534
#
#
# Error:
# Mean absolute error: 0.10499984629655862
# ...

# %% [markdown]
# # Cross Validation

# %%
#cross validating the models
from sklearn.model_selection import cross_val_score
model=[LinearRegression(), RandomForestRegressor(), DecisionTreeRegressor(), KNeighborsRegressor(), SVR(), Lasso(), Ridge(), ElasticNet()]
for m in model:
    score=cross_val_score(m, x, y, cv=5, scoring='r2')
    print('Score of', m, 'is:')
    print('\n')
    print('Score :', score)
    print('Mean Score :', score.mean())
    print('Standard deviation:', score.std())
    print('\n')
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is:
#
#
# Score : [0.82440144 0.81365555 0.80060263 0.78303409 0.78135931]
# Mean Score : 0.8006106052624725
# Standard deviation: 0.016826885915638
#
#
# *******************************************************************************************************
#
#
# Score of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) is:
#
#
# Score : [0.95049709 0.99088405 0.97353481 0.99446908 0.92424377]
# Mean Score : 0.9667257584923934
# ...

# %% [markdown]
# From the above anlysis we can see that RandomForestRegressor & DecisionTreeRegressor are working as best models.

# %% [markdown]
# # Random Forest Regressor

# %%
#Using Random Forest model with best reults

from sklearn.ensemble import RandomForestRegressor
rf1=RandomForestRegressor()
rf1.fit(x_train, y_train)
print('Score:', rf1.score(x_train, y_train))
predrf=rf1.predict(x_test)
print('\n')
print('Mean absolute error:', mean_absolute_error(y_test, predrf))
print('Mean squared error:', mean_squared_error(y_test, predrf))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, predrf)))
print('\n')
print('r2_score:', r2_score(y_test, predrf))
# Out:
# Score: 0.9982782202286078
#
#
# Mean absolute error: 0.104104983453986
# Mean squared error: 0.08616706617378547
# Root mean squared error: 0.29354227323127663
#
#
# r2_score: 0.9910933181233171

# %%
#cross validating the RandomForestRegressor model

score=cross_val_score(rf1, x, y, cv=5, scoring='r2')
print('Score of', rf1, 'is:')
print('\n')
print('Score :', score)
print('Mean Score :', score.mean())
print('Standard deviation:', score.std())
# Out:
# Score of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) is:
#
#
# Score : [0.9521851  0.99114925 0.97313472 0.99379084 0.92901674]
# Mean Score : 0.9678553309326077
# Standard deviation: 0.02448314254111285

# %% [markdown]
# # Decision Tree Regressor

# %%
#Using DecisionTreeRegressor with best reults

from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train, y_train)
print('Score:', dtr.score(x_train, y_train))
predtr=dtr.predict(x_test)
print('\n')
print('Mean absolute error:', mean_absolute_error(y_test, predtr))
print('Mean squared error:', mean_squared_error(y_test, predtr))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, predtr)))
print('\n')
print('r2_score:', r2_score(y_test, predtr))
# Out:
# Score: 1.0
#
#
# Mean absolute error: 0.08587831416583798
# Mean squared error: 0.09154953414914026
# Root mean squared error: 0.3025715355897515
#
#
# r2_score: 0.9905369578792393

# %%
#cross validating the DecisionTreeRegressor model

score=cross_val_score(dtr, x, y, cv=5, scoring='r2')
print('Score of', dtr, 'is:')
print('\n')
print('Score :', score)
print('Mean Score :', score.mean())
print('Standard deviation:', score.std())
# Out:
# Score of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') is:
#
#
# Score : [0.86026397 0.96903524 0.92628873 0.96391354 0.77048849]
# Mean Score : 0.8979979945746784
# Standard deviation: 0.07466464291356299

# %% [markdown]
# # Finalising the Random Forest Regressor model.

# %%
#Model result r2 score and cross val score are found to be best in Random Forest Regressor, so finalising the rfr model.

# Saving the finalised rfr model with accuracy score of - 0.9979

from sklearn.externals import joblib

#save the model as a pickle in a file
joblib.dump(rf1, 'rf1.Country_wide_COVID 19.pkl')
# Out:
# ['rf1.Country_wide_COVID 19.pkl']

# %% [markdown]
# # True death rate of COVID-19 and examine the relationship with age

# %% [markdown]
# Analyzing the Age Dataset

# %%
ds2.head()
# Out:
#   Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0     USA                    0.189                     0.657
# 1  Russia                    0.176                     0.682
# 2   Spain                    0.147                     0.659
# 3  Brazil                    0.217                     0.697
# 4      UK                    0.177                     0.638
#
#    Fraction age 65+ years
# 0                   0.154
# 1                   0.142
# 2                   0.194
# 3                   0.086
# 4                   0.185

# %%
df2=pd.DataFrame(ds2)
df2
# Out:
#                    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0                      USA                    0.189                     0.657
# 1                   Russia                    0.176                     0.682
# 2                    Spain                    0.147                     0.659
# 3                   Brazil                    0.217                     0.697
# 4                       UK                    0.177                     0.638
# ..                     ...                      ...                       ...
# 208              St. Barth                      NaN                       NaN
# 209         Western Sahara                      NaN                       NaN
# 210               Anguilla                      NaN                       NaN
# 211                Lesotho                    0.354                     0.601
# 212  Saint Pierre Miquelon                      NaN                       NaN
#
#      Fraction age 65+ years
# ...

# %%
df2.shape
# Out:
# (213, 4)

# %%
df2.dtypes
# Out:
# Country                      object
# Fraction age 0-14 years     float64
# Fraction age 15-64 years    float64
# Fraction age 65+ years      float64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Country', 'Fraction age 0-14 years', 'Fraction age 15-64 years',
#        'Fraction age 65+ years'],
#       dtype='object')

# %%
#Printing the object data type columns and their unique values

for column in df2.columns:
    if df2[column].dtypes==object:
        print(str(column)+ ' : ' +str(df2[column].unique()))
        print(df2[column].value_counts())
        print('***************************************************************************')
        print('\n')
# Out:
# Country : ['USA' 'Russia' 'Spain' 'Brazil' 'UK' 'Italy' 'France' 'Germany' 'Turkey'
#  'Iran' 'India' 'Peru' 'China' 'Canada' 'Saudi Arabia' 'Belgium' 'Mexico'
#  'Chile' 'Netherlands' 'Pakistan' 'Qatar' 'Ecuador' 'Switzerland'
#  'Belarus' 'Sweden' 'Portugal' 'Singapore' 'Ireland' 'UAE' 'Bangladesh'
#  'Poland' 'Ukraine' 'Indonesia' 'Romania' 'Israel' 'South Africa' 'Japan'
#  'Colombia' 'Austria' 'Kuwait' 'Egypt' 'Dominican Republic' 'Philippines'
#  'S. Korea' 'Denmark' 'Serbia' 'Panama' 'Czechia' 'Argentina' 'Norway'
#  'Algeria' 'Bahrain' 'Afghanistan' 'Australia' 'Morocco' 'Malaysia'
#  'Kazakhstan' 'Finland' 'Nigeria' 'Moldova' 'Ghana' 'Oman' 'Armenia'
#  'Bolivia' 'Luxembourg' 'Iraq' 'Hungary' 'Cameroon' 'Azerbaijan'
#  'Thailand' 'Greece' 'Guinea' 'Uzbekistan' 'Honduras' 'Sudan' 'Senegal'
#  'Bosnia and Herzegovina' 'Bulgaria' 'Croatia' 'Ivory Coast' 'Guatemala'
#  'Cuba' 'North Macedonia' 'Iceland' 'Estonia' 'Tajikistan' 'Lithuania'
# ...

# %%
df2.isnull().sum()
# Out:
# Country                      0
# Fraction age 0-14 years     37
# Fraction age 15-64 years    37
# Fraction age 65+ years      37
# dtype: int64

# %%
# Replacing null values in the dataset

#Replacing "Fraction age 0-14 years" column null values with mean
df2['Fraction age 0-14 years']=df2['Fraction age 0-14 years'].fillna(df2['Fraction age 0-14 years'].mean())

#Replacing "Fraction age 15-64 years" column null values with mean
df2['Fraction age 15-64 years']=df2['Fraction age 15-64 years'].fillna(df2['Fraction age 15-64 years'].mean())

#Replacing "Fraction age 65+ years" column null values with mean
df2['Fraction age 65+ years']=df2['Fraction age 65+ years'].fillna(df2['Fraction age 65+ years'].mean())

# %%
df2.isnull().sum()
# Out:
# Country                     0
# Fraction age 0-14 years     0
# Fraction age 15-64 years    0
# Fraction age 65+ years      0
# dtype: int64

# %%
df2.head()
# Out:
#   Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0     USA                    0.189                     0.657
# 1  Russia                    0.176                     0.682
# 2   Spain                    0.147                     0.659
# 3  Brazil                    0.217                     0.697
# 4      UK                    0.177                     0.638
#
#    Fraction age 65+ years
# 0                   0.154
# 1                   0.142
# 2                   0.194
# 3                   0.086
# 4                   0.185

# %%
#Coutry vs Fraction age 0-14 years

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Fraction age 0-14 years', data=df2)
plt.title('Coutry wise Fraction of age - 0 to 14 years', fontsize=30)
plt.show()

# %%
#Coutry vs Fraction age 15-64 years

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Fraction age 15-64 years', data=df2)
plt.title('Coutry wise Fraction of age - 15-64 years', fontsize=30)
plt.show()

# %%
#Coutry vs Fraction age 65+ years

plt.figure(figsize=(20, 50))
sns.barplot(y='Country', x='Fraction age 65+ years', data=df2)
plt.title('Coutry wise Fraction of age - 65+ years', fontsize=30)
plt.show()

# %%
ds3=pd.read_csv('Country_wide_COVID 19_Datasets.csv')
ds3.head()
# Out:
#          Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0  2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1  2020-04-18  Russia   145927292    1831892.0      36793.0         313.0
# 2  2020-04-18   Spain    46752703     930230.0     194416.0       20043.0
# 3  2020-04-18  Brazil   212380932      62985.0      36722.0        2361.0
# 4  2020-04-18      UK    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases
# 0          68269.0              13551.0      631509.0
# 1           3057.0                  8.0       33423.0
# 2          74797.0               7371.0       99576.0
# 3          14026.0               6634.0       20335.0
# 4              NaN               1559.0       98409.0

# %%
# changing the Date column into actual date format

ds3['Date'] = pd.to_datetime(ds3['Date'])

# %%
# Now lets replace the categorical values (alphabetic values) to numeric values using Label Encoder
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Lets Encode labels in columns 
ds3['Country']= label_encoder.fit_transform(ds3['Country'])

# %%
#Splitting date/month/year format

ds3["day"]=ds3["Date"].dt.day
ds3["month"]=ds3["Date"].dt.month
ds3["year"]=ds3["Date"].dt.year
ds3.head()
# Out:
#         Date  Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0 2020-04-18      201   330774664    3722145.0     738792.0       39014.0
# 1 2020-04-18      158   145927292    1831892.0      36793.0         313.0
# 2 2020-04-18      180    46752703     930230.0     194416.0       20043.0
# 3 2020-04-18       26   212380932      62985.0      36722.0        2361.0
# 4 2020-04-18      200    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases  day  month  year
# 0          68269.0              13551.0      631509.0   18      4  2020
# 1           3057.0                  8.0       33423.0   18      4  2020
# 2          74797.0               7371.0       99576.0   18      4  2020
# 3          14026.0               6634.0       20335.0   18      4  2020
# 4              NaN               1559.0       98409.0   18      4  2020

# %%
#As we have added date/month/year column to the dataset we can drop the "Date" column.

ds3=ds3.drop(['Date'], axis=1)
ds3.head()
# Out:
#    Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0      201   330774664    3722145.0     738792.0       39014.0
# 1      158   145927292    1831892.0      36793.0         313.0
# 2      180    46752703     930230.0     194416.0       20043.0
# 3       26   212380932      62985.0      36722.0        2361.0
# 4      200    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases  day  month  year
# 0          68269.0              13551.0      631509.0   18      4  2020
# 1           3057.0                  8.0       33423.0   18      4  2020
# 2          74797.0               7371.0       99576.0   18      4  2020
# 3          14026.0               6634.0       20335.0   18      4  2020
# 4              NaN               1559.0       98409.0   18      4  2020

# %%
# Replacing null values with Imputer

from sklearn.impute import KNNImputer
x=ds3
imputer = KNNImputer(n_neighbors=4)
x = imputer.fit_transform(x.values)
x = pd.DataFrame(x, columns=ds3.columns)
x.head()
# Out:
#    Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0    201.0  330774664.0    3722145.0     738792.0       39014.0
# 1    158.0  145927292.0    1831892.0      36793.0         313.0
# 2    180.0   46752703.0     930230.0     194416.0       20043.0
# 3     26.0  212380932.0      62985.0      36722.0        2361.0
# 4    200.0   67844241.0     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases   day  month    year
# 0          68269.0              13551.0      631509.0  18.0    4.0  2020.0
# 1           3057.0                  8.0       33423.0  18.0    4.0  2020.0
# 2          74797.0               7371.0       99576.0  18.0    4.0  2020.0
# 3          14026.0               6634.0       20335.0  18.0    4.0  2020.0
# 4           2855.5               1559.0       98409.0  18.0    4.0  2020.0

# %%
df3=x
df3.head()
# Out:
#    Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0    201.0  330774664.0    3722145.0     738792.0       39014.0
# 1    158.0  145927292.0    1831892.0      36793.0         313.0
# 2    180.0   46752703.0     930230.0     194416.0       20043.0
# 3     26.0  212380932.0      62985.0      36722.0        2361.0
# 4    200.0   67844241.0     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases   day  month    year
# 0          68269.0              13551.0      631509.0  18.0    4.0  2020.0
# 1           3057.0                  8.0       33423.0  18.0    4.0  2020.0
# 2          74797.0               7371.0       99576.0  18.0    4.0  2020.0
# 3          14026.0               6634.0       20335.0  18.0    4.0  2020.0
# 4           2855.5               1559.0       98409.0  18.0    4.0  2020.0

# %%
df2
# Out:
#                    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0                      USA                 0.189000                  0.657000
# 1                   Russia                 0.176000                  0.682000
# 2                    Spain                 0.147000                  0.659000
# 3                   Brazil                 0.217000                  0.697000
# 4                       UK                 0.177000                  0.638000
# ..                     ...                      ...                       ...
# 208              St. Barth                 0.276098                  0.636109
# 209         Western Sahara                 0.276098                  0.636109
# 210               Anguilla                 0.276098                  0.636109
# 211                Lesotho                 0.354000                  0.601000
# 212  Saint Pierre Miquelon                 0.276098                  0.636109
#
#      Fraction age 65+ years
# ...

# %%
# Lets Encode labels in columns 
df2['Country']= label_encoder.fit_transform(df2['Country'])
df2.head()
# Out:
#    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0      201                    0.189                     0.657
# 1      158                    0.176                     0.682
# 2      180                    0.147                     0.659
# 3       26                    0.217                     0.697
# 4      200                    0.177                     0.638
#
#    Fraction age 65+ years
# 0                   0.154
# 1                   0.142
# 2                   0.194
# 3                   0.086
# 4                   0.185

# %%
df=pd.merge(df3, df2, on='Country')
df
# Out:
#       Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0       201.0  330774664.0    3722145.0     738792.0      39014.00
# 1       201.0  330774664.0    3861549.0     763832.0      40553.00
# 2       201.0  330774664.0    4026360.0     792759.0      42514.00
# 3       201.0  330774664.0    4187392.0     818744.0      45318.00
# 4       201.0  330774664.0    4325342.0     848717.0      47659.00
# ...       ...          ...          ...          ...           ...
# 6598    165.0       5797.0         36.0          1.0          0.75
# 6599    165.0       5797.0         36.0          1.0          0.75
# 6600    165.0       5797.0         36.0          1.0          0.75
# 6601    165.0       5797.0         36.0          1.0          0.75
# 6602    165.0       5797.0         36.0          1.0          0.75
#
#       Total Recovered  Serious or Critical  Active Cases   day  month    year  \
# 0             68269.0              13551.0      631509.0  18.0    4.0  2020.0
# ...

# %%
#As we have merged the files now we can anaylse the agewise Total Tests', 'Total Cases', 'Total Deaths', 'Total Recovered', 'Serious or Critical', 'Active Cases.

#Age wise Population
df['Population age 0-14 years'] = df["Population"]*df["Fraction age 0-14 years"]
df['Population age 15-64 years'] = df["Population"]*df["Fraction age 15-64 years"]
df['Population age 65+ years'] = df["Population"]*df["Fraction age 65+ years"]


#Age wise Total Cases
df['Total Tests age 0-14 years'] = df["Total Tests"]*df["Fraction age 0-14 years"]
df['Total Tests age 15-64 years'] = df["Total Tests"]*df["Fraction age 15-64 years"]
df['Total Tests age 65+ years'] = df["Total Tests"]*df["Fraction age 65+ years"]


#Age wise Total Cases
df['Total Cases age 0-14 years'] = df["Total Cases"]*df["Fraction age 0-14 years"]
df['Total Cases age 15-64 years'] = df["Total Cases"]*df["Fraction age 15-64 years"]
df['Total Cases age 65+ years'] = df["Total Cases"]*df["Fraction age 65+ years"]


#Age wise Total Deaths
df['Total Deaths age 0-14 years'] = df["Total Deaths"]*df["Fraction age 0-14 years"]
df['Total Deaths age 15-64 years'] = df["Total Deaths"]*df["Fraction age 15-64 years"]
df['Total Deaths age 65+ years'] = df["Total Deaths"]*df["Fraction age 65+ years"]


#Age wise Total Recovered
df['Total Recovered age 0-14 years'] = df["Total Recovered"]*df["Fraction age 0-14 years"]
df['Total Recovered age 15-64 years'] = df["Total Recovered"]*df["Fraction age 15-64 years"]
df['Total Recovered age 65+ years'] = df["Total Recovered"]*df["Fraction age 65+ years"]


#Age wise Serious or Critical
df['Serious or Critical age 0-14 years'] = df["Serious or Critical"]*df["Fraction age 0-14 years"]
df['Serious or Critical age 15-64 years'] = df["Serious or Critical"]*df["Fraction age 15-64 years"]
df['Serious or Critical age 65+ years'] = df["Serious or Critical"]*df["Fraction age 65+ years"]


#Age wise Serious or Critical
df['Active Cases age 0-14 years'] = df["Active Cases"]*df["Fraction age 0-14 years"]
df['Active Cases age 15-64 years'] = df["Active Cases"]*df["Fraction age 15-64 years"]
df['Active Cases age 65+ years'] = df["Active Cases"]*df["Fraction age 65+ years"]

# %%
df
# Out:
#       Country   Population  Total Tests  Total Cases  Total Deaths  \
# 0       201.0  330774664.0    3722145.0     738792.0      39014.00
# 1       201.0  330774664.0    3861549.0     763832.0      40553.00
# 2       201.0  330774664.0    4026360.0     792759.0      42514.00
# 3       201.0  330774664.0    4187392.0     818744.0      45318.00
# 4       201.0  330774664.0    4325342.0     848717.0      47659.00
# ...       ...          ...          ...          ...           ...
# 6598    165.0       5797.0         36.0          1.0          0.75
# 6599    165.0       5797.0         36.0          1.0          0.75
# 6600    165.0       5797.0         36.0          1.0          0.75
# 6601    165.0       5797.0         36.0          1.0          0.75
# 6602    165.0       5797.0         36.0          1.0          0.75
#
#       Total Recovered  Serious or Critical  Active Cases   day  month  ...  \
# 0             68269.0              13551.0      631509.0  18.0    4.0  ...
# ...

# %% [markdown]
# # Death Rate of COVID-19 and Examining the Relationship with Age

# %%
#Death rate of COVID-19 and examine the relationship with age

Covid_Death = df[['Country', 'Population', 'Total Deaths', 'Total Deaths age 0-14 years', 'Total Deaths age 15-64 years', 'Total Deaths age 65+ years']]
Covid_Death
# Out:
#       Country   Population  Total Deaths  Total Deaths age 0-14 years  \
# 0       201.0  330774664.0      39014.00                  7373.646000
# 1       201.0  330774664.0      40553.00                  7664.517000
# 2       201.0  330774664.0      42514.00                  8035.146000
# 3       201.0  330774664.0      45318.00                  8565.102000
# 4       201.0  330774664.0      47659.00                  9007.551000
# ...       ...          ...           ...                          ...
# 6598    165.0       5797.0          0.75                     0.207073
# 6599    165.0       5797.0          0.75                     0.207073
# 6600    165.0       5797.0          0.75                     0.207073
# 6601    165.0       5797.0          0.75                     0.207073
# 6602    165.0       5797.0          0.75                     0.207073
#
#       Total Deaths age 15-64 years  Total Deaths age 65+ years
# 0                     25632.198000                 6008.156000
# ...

# %%
df2.columns
# Out:
# Index(['Country', 'Fraction age 0-14 years', 'Fraction age 15-64 years',
#        'Fraction age 65+ years'],
#       dtype='object')

# %%
df1['Total Tests'].mean()
# Out:
# 35.1799075542832

# %%
df1['Total Tests'].median()
# Out:
# 25.8776300935318
