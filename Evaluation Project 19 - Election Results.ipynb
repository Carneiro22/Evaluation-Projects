# %% [markdown]
# # Election Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
ds=pd.read_csv('ElectionData.csv')
ds
# Out:
#        TimeElapsed                 time        territoryName  totalMandates  \
# 0                0  2019-10-06 20:10:02  Território Nacional              0
# 1                0  2019-10-06 20:10:02  Território Nacional              0
# 2                0  2019-10-06 20:10:02  Território Nacional              0
# 3                0  2019-10-06 20:10:02  Território Nacional              0
# 4                0  2019-10-06 20:10:02  Território Nacional              0
# ...            ...                  ...                  ...            ...
# 21638          265  2019-10-07 00:35:01                Viseu              8
# 21639          265  2019-10-07 00:35:01                Viseu              8
# 21640          265  2019-10-07 00:35:01                Viseu              8
# 21641          265  2019-10-07 00:35:01                Viseu              8
# 21642          265  2019-10-07 00:35:01                Viseu              8
#
# ...

# %%
ds.shape
# Out:
# (21643, 28)

# %%
ds.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# ...

# %% [markdown]
# Some relevant columns in the dataset:
#
# 1. TimeElapsed (Numeric): Time (minutes) passed since the first data acquisition
#
# 2. time (timestamp): Date and time of the data acquisition
#
# 3. territoryName (string): Short name of the location (district or nation-wide)
#
# 4. totalMandates (numeric): MP's elected at the moment
#
# 5. availableMandates (numeric): MP's left to elect at the moment
#
# 6. numParishes (numeric): Total number of parishes in this location
#
# 7. numParishesApproved (numeric): Number of parishes approved in this location
#
# 8. blankVotes (numeric): Number of blank votes
#
# 9. blankVotesPercentage (numeric): Percentage of blank votes
#
# 10. nullVotes (numeric): Number of null votes
#
# 11. nullVotesPercentage (numeric): Percentage of null votes
#
# 12. votersPercentage (numeric): Percentage of voters
#
# 13. subscribedVoters (numeric): Number of subscribed voters in the location
#
# 14. totalVoters (numeric): Percentage of blank votes
#
# 15. pre.blankVotes (numeric): Number of blank votes (previous election)
#
# 16. pre.blankVotesPercentage (numeric): Percentage of blank votes (previous election)
#
# 17. pre.nullVotes (numeric): Number of null votes (previous election)
#
# 18. pre.nullVotesPercentage (numeric): Percentage of null votes (previous election)
#
# 19. pre.votersPercentage (numeric): Percentage of voters (previous election)
#
# 20. pre.subscribedVoters (numeric): Number of subscribed voters in the location (previous election)
#
# 21. pre.totalVoters (numeric): Percentage of blank votes (previous election)
#
# 22. Party (string): Political Party
#
# 23. Mandates (numeric): MP's elected at the moment for the party in a given district
#
# 24. Percentage (numeric): Percentage of votes in a party
#
# 25. validVotesPercentage (numeric): Percentage of valid votes in a party
#
# 26. Votes (numeric): Percentage of party votes
#
# 27. Hondt (numeric): Number of MP's according to the distribution of votes now
#
# 28. FinalMandates (numeric): Target: final number of elected MP's in a district/national-level

# %%
ds.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
df=pd.DataFrame(ds)
df.head()
# Out:
#    TimeElapsed                 time        territoryName  totalMandates  \
# 0            0  2019-10-06 20:10:02  Território Nacional              0
# 1            0  2019-10-06 20:10:02  Território Nacional              0
# 2            0  2019-10-06 20:10:02  Território Nacional              0
# 3            0  2019-10-06 20:10:02  Território Nacional              0
# 4            0  2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
#Seeing the null values with the help of heat map

plt.figure(figsize=(14, 10))
sns.heatmap(df.isnull(),yticklabels=False, cbar=False)

# %%
#Printing the object data type columns and their unique values

for column in df.columns:
    if df[column].dtypes==object:
        print(str(column)+ ' : ' +str(df[column].unique()))
        print(df[column].value_counts())
        print('***************************************************************************')
        print('\n')
# Out:
# time : ['2019-10-06 20:10:02' '2019-10-06 20:15:02' '2019-10-06 20:20:02'
#  '2019-10-06 20:25:02' '2019-10-06 20:30:02' '2019-10-06 20:35:02'
#  '2019-10-06 20:40:02' '2019-10-06 20:45:02' '2019-10-06 20:50:01'
#  '2019-10-06 20:55:01' '2019-10-06 21:00:01' '2019-10-06 21:05:01'
#  '2019-10-06 21:10:01' '2019-10-06 21:15:02' '2019-10-06 21:20:02'
#  '2019-10-06 21:25:02' '2019-10-06 21:30:01' '2019-10-06 21:35:01'
#  '2019-10-06 21:40:02' '2019-10-06 21:45:02' '2019-10-06 21:50:01'
#  '2019-10-06 21:55:01' '2019-10-06 22:00:02' '2019-10-06 22:05:02'
#  '2019-10-06 22:10:01' '2019-10-06 22:15:01' '2019-10-06 22:20:02'
#  '2019-10-06 22:25:01' '2019-10-06 22:30:01' '2019-10-06 22:35:01'
#  '2019-10-06 22:40:02' '2019-10-06 22:45:01' '2019-10-06 22:50:01'
#  '2019-10-06 22:55:02' '2019-10-06 23:00:01' '2019-10-06 23:05:01'
#  '2019-10-06 23:10:02' '2019-10-06 23:15:01' '2019-10-06 23:20:01'
#  '2019-10-06 23:25:02' '2019-10-06 23:30:01' '2019-10-06 23:35:02'
# ...

# %%
#Checking the summary of the dataset

df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %% [markdown]
# # To Check Correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# ...

# %%
#Heatmap

plt.figure(figsize=(22, 18))
sns.heatmap(df_cor, annot=True, fmt='.0%', cmap='BuPu')
plt.show()

# %% [markdown]
# Correlation with target column

# %%
#Correlation with target column

plt.figure(figsize=(18, 8))
df.drop('FinalMandates', axis=1).corrwith(df['FinalMandates']).plot(kind='bar', grid=True)
plt.xticks(rotation='vertical')
plt.title("Correlation with target variable")
# Out:
# Text(0.5, 1.0, 'Correlation with target variable')

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %% [markdown]
# # Data Visualization

# %%
#Checking the number of FinalMandates.

plt.figure(figsize=(12, 6))
sns.countplot(x='FinalMandates', data=df, palette='rainbow')
plt.title('Number of elected MPs in a district/national-level', fontsize=18)
plt.show()

print(df['FinalMandates'].value_counts())
# Out:
# 0      17823
# 1       1134
# 2        695
# 3        641
# 4        378
# 5        270
# 8        108
# 12       108
# 7         54
# 6         54
# 77        54
# 20        54
# 19        54
# 9         54
# 106       54
# 17        54
# 15        54
# Name: FinalMandates, dtype: int64

# %%
#Checking the territory Names.

plt.figure(figsize=(16, 12))
sns.countplot(y='territoryName', data=df, palette='rainbow')
plt.title('Short name of the location (district or nation-wide)', fontsize=20)
plt.show()

print(df['territoryName'].value_counts())
# Out:
# Porto                  1134
# Leiria                 1134
# Território Nacional    1134
# Braga                  1134
# Viana do Castelo       1080
# Madeira                1080
# Setúbal                1080
# Coimbra                1080
# Viseu                  1080
# Lisboa                 1080
# Aveiro                 1080
# Faro                   1026
# Guarda                 1026
# Santarém               1026
# Évora                  1026
# Castelo Branco          972
# Bragança                972
# Beja                    918
# Portalegre              918
# Vila Real               864
# Açores                  799
# Name: territoryName, dtype: int64

# %%
#Checking the total Mandates.

plt.figure(figsize=(22, 8))
sns.countplot(x='totalMandates', data=df, palette='rainbow')
plt.title('MPs elected at the moment', fontsize=24)
plt.show()

print(df['totalMandates'].value_counts())
# Out:
# 0      5055
# 3      2949
# 2      1755
# 9      1726
# 6      1419
#        ...
# 22       21
# 197      21
# 149      21
# 37       21
# 17       20
# Name: totalMandates, Length: 62, dtype: int64

# %%
#Checking the available Mandates.

plt.figure(figsize=(22, 8))
sns.countplot(x='availableMandates', data=df, palette='rainbow')
plt.title('MPs left to elect at the moment', fontsize=24)
plt.show()

print(df['availableMandates'].value_counts())
# Out:
# 0      9686
# 3      1873
# 6      1201
# 9      1150
# 4      1089
#        ...
# 101      21
# 37       21
# 212      21
# 175      21
# 44       20
# Name: availableMandates, Length: 69, dtype: int64

# %%
#Checking the Total number of parishes in this location

plt.figure(figsize=(12, 6))
sns.countplot(x='numParishes', data=df, palette='rainbow')
plt.title('Total number of parishes in this location', fontsize=18)
plt.show()

print(df['numParishes'].value_counts())
# Out:
# 69      1944
# 110     1134
# 243     1134
# 3092    1134
# 347     1134
# 155     1080
# 55      1080
# 134     1080
# 54      1080
# 277     1080
# 147     1080
# 208     1080
# 141     1026
# 67      1026
# 242     1026
# 120      972
# 226      972
# 75       918
# 197      864
# 156      799
# Name: numParishes, dtype: int64

# %%
#Checking the Total Percentage of null votes

plt.figure(figsize=(28, 26))
sns.countplot(y='nullVotesPercentage', data=df, palette='rainbow')
plt.title('Total Percentage of null votes', fontsize=26)
plt.show()

print(df['nullVotesPercentage'].value_counts())
# Out:
# 1.77    1117
# 1.63     824
# 1.93     791
# 1.78     728
# 2.30     701
#         ...
# 2.51      18
# 2.67      18
# 1.35      17
# 2.46      16
# 2.70      16
# Name: nullVotesPercentage, Length: 107, dtype: int64

# %%
#Checking the Total number of Political Party

plt.figure(figsize=(16, 6))
sns.countplot(x='Party', data=df, palette='rainbow')
plt.title('Total number of Political Party', fontsize=18)
plt.show()

print(df['Party'].value_counts())
# Out:
# IL           1127
# B.E.         1127
# PDR          1127
# PS           1127
# PNR          1127
# PCTP/MRPP    1127
# L            1127
# CH           1127
# A            1127
# PPD/PSD      1127
# PAN          1127
# CDS-PP       1127
# PCP-PEV      1127
# PPM          1073
# R.I.R.       1026
# PTP          1019
# MPT          1019
# NC            972
# PURP          972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
#Checking the Number of MP's according to the distribution of votes now

plt.figure(figsize=(16, 6))
sns.countplot(x='Hondt', data=df, palette='rainbow')
plt.title('Number of MPs according to the distribution of votes now', fontsize=18)
plt.show()

print(df['Hondt'].value_counts())
# Out:
# 0     17754
# 1      1137
# 2       723
# 3       696
# 4       316
# 5       212
# 7       107
# 8        98
# 9        77
# 15       76
# 20       61
# 12       47
# 10       39
# 17       37
# 6        37
# 23       28
# 14       21
# 90       16
# 91       16
# 18       16
# 22       15
# 11       15
# 69       14
# 94       13
# 16       11
# 70        7
# 92        7
# 76        7
# 82        7
# 13        6
# 71        5
# 73        4
# 74        3
# 21        3
# 19        3
# 68        2
# 72        2
# 93        2
# 77        1
# 81        1
# 75        1
# Name: Hondt, dtype: int64

# %%
#Checking totalMandates vs territoryName

plt.figure(figsize=(12, 8))
mean_amount=np.mean(df['totalMandates'])
sns.boxplot(x='totalMandates', y='territoryName', data=df, palette='rainbow')
plt.axhline(mean_amount, color='r', linestyle='dashed', linewidth=2)
plt.title("Total Mandates vs Territory Name", fontsize=20)
plt.show()

# %%
#Checking Available Mandates vs Territory Name

plt.figure(figsize=(12, 8))
mean_amount=np.mean(df['availableMandates'])
sns.boxplot(x='availableMandates', y='territoryName', data=df, palette='rainbow')
plt.axhline(mean_amount, color='r', linestyle='dashed', linewidth=2)
plt.title("Available Mandates vs Territory Name", fontsize=20)
plt.show()

# %%
for col in df.describe().columns:
    sns.distplot(df[col], kde_kws={'bw': 0.1}, color='r')
    plt.show()

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# ...

# %%
#Dropping the 'TimeElapsed & time' column from the datset

df=df.drop(['TimeElapsed'], axis=1)
df=df.drop(['time'], axis=1)
df.head()
# Out:
#          territoryName  totalMandates  availableMandates  numParishes  \
# 0  Território Nacional              0                226         3092
# 1  Território Nacional              0                226         3092
# 2  Território Nacional              0                226         3092
# 3  Território Nacional              0                226         3092
# 4  Território Nacional              0                226         3092
#
#    numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0                 1081        9652                   2.5       8874
# 1                 1081        9652                   2.5       8874
# 2                 1081        9652                   2.5       8874
# 3                 1081        9652                   2.5       8874
# 4                 1081        9652                   2.5       8874
#
#    nullVotesPercentage  votersPercentage  ...  pre.votersPercentage  \
# ...

# %% [markdown]
# Converting the categorical data into numeric variables

# %%
from sklearn.preprocessing import LabelEncoder
  
# label_encoder object knows how to understand word labels. 
le = LabelEncoder() 
  
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    df[column]=le.fit_transform(df[column])

# %%
df.head()
# Out:
#    territoryName  totalMandates  availableMandates  numParishes  \
# 0             16              0                 68           19
# 1             16              0                 68           19
# 2             16              0                 68           19
# 3             16              0                 68           19
# 4             16              0                 68           19
#
#    numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0                  181         244                   2.5        266
# 1                  181         244                   2.5        266
# 2                  181         244                   2.5        266
# 3                  181         244                   2.5        266
# 4                  181         244                   2.5        266
#
#    nullVotesPercentage  votersPercentage  ...  pre.votersPercentage  \
# 0                  2.3             51.36  ...                 52.66
# ...

# %%
df.hist(figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000014D5A293D48>,
# ...
#       dtype=object)

# %%
#sns.pairplot(df)

# %%
collist=df.columns.values
ncol=5
nrow=6

plt.figure(figsize=(10, 20))
for i in range(0, len(collist)):
    plt.subplot(nrow, ncol, i+1)
    sns.boxplot(df[collist[i]], color='purple', orient='v')
    plt.tight_layout()

# %%
df.describe()
# Out:
#        territoryName  totalMandates  availableMandates   numParishes  \
# count   21643.000000   21643.000000       21643.000000  21643.000000
# mean       10.116851       7.341034           7.374347      9.290902
# std         5.985225      10.843243          13.523426      5.889671
# min         0.000000       0.000000           0.000000      0.000000
# 25%         5.000000       1.000000           0.000000      4.000000
# 50%        10.000000       4.000000           2.000000      9.000000
# 75%        15.000000       9.000000           8.000000     15.000000
# max        20.000000      61.000000          68.000000     19.000000
#
#        numParishesApproved    blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000  21643.000000          21643.000000  21643.000000
# mean             87.559396    138.992145              2.621629    143.210368
# std              55.826565     91.362076              0.795289     90.276924
# ...

# %%
df.skew()
# Out:
# territoryName               -0.025884
# totalMandates                2.740064
# availableMandates            2.636014
# numParishes                  0.080209
# numParishesApproved          0.325649
# blankVotes                   0.221028
# blankVotesPercentage         0.069627
# nullVotes                    0.148929
# nullVotesPercentage          0.855419
# votersPercentage            -1.158029
# subscribedVoters             0.141035
# totalVoters                  0.153941
# pre.blankVotes               0.213706
# pre.blankVotesPercentage     0.021609
# pre.nullVotes                0.091053
# pre.nullVotesPercentage      1.231109
# pre.votersPercentage        -0.779289
# pre.subscribedVoters         0.108684
# pre.totalVoters              0.128062
# Party                       -0.083536
# Mandates                    13.785061
# Percentage                   2.542328
# validVotesPercentage         2.543122
# Votes                        0.871851
# Hondt                        6.721992
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[ 0.98296816,  0.67703029,  4.48311344, ...,  2.25359413,
#         11.58720546,  7.16061227],
#        [ 0.98296816,  0.67703029,  4.48311344, ...,  2.22922591,
#          9.81000328,  6.69307153],
#        [ 0.98296816,  0.67703029,  4.48311344, ...,  1.68181142,
#          4.47839675,  5.75799006],
#        ...,
#        [ 1.48421407,  0.06077344,  0.54531431, ...,  0.82115217,
#          0.26080905,  0.32003955],
#        [ 1.48421407,  0.06077344,  0.54531431, ...,  0.83594715,
#          0.26080905,  0.32003955],
#        [ 1.48421407,  0.06077344,  0.54531431, ...,  0.93951206,
#          0.26080905,  0.32003955]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    0,     0,     0, ..., 21608, 21623, 21623], dtype=int64), array([ 2, 21, 22, ..., 22, 21, 22], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape, '\t', df_new.shape)
# Out:
# (21643, 26) 	 (18181, 26)

# %%
df=df_new
print(df.shape)
# Out:
# (18181, 26)

# %% [markdown]
# # Model Training

# %%
#seprating into input and output variables

df_x=df.drop(columns=['FinalMandates'])

y=pd.DataFrame(df['FinalMandates'])

# %%
#scaling the input variable 
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x, columns=df_x.columns)
x.head()
# Out:
#    territoryName  totalMandates  availableMandates  numParishes  \
# 0            0.0            0.0           0.340909          0.5
# 1            0.0            0.0           0.340909          0.5
# 2            0.0            0.0           0.340909          0.5
# 3            0.0            0.0           0.340909          0.5
# 4            0.0            0.0           0.340909          0.5
#
#    numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0             0.022346    0.017301              0.715569   0.006826
# 1             0.022346    0.017301              0.715569   0.006826
# 2             0.022346    0.017301              0.715569   0.006826
# 3             0.022346    0.017301              0.715569   0.006826
# 4             0.022346    0.017301              0.715569   0.006826
#
#    nullVotesPercentage  votersPercentage  ...  pre.nullVotesPercentage  \
# 0              0.15528          0.613302  ...                 0.273743
# ...

# %%
#treating skewness via log method

for col in x.columns:
    if x[col].skew()>0.55:
        x[col]=np.log1p(x[col])

# %%
x.skew()
# Out:
# territoryName               -0.025884
# totalMandates                2.262512
# availableMandates            2.263442
# numParishes                  0.080209
# numParishesApproved          0.325649
# blankVotes                   0.221028
# blankVotesPercentage         0.069627
# nullVotes                    0.148929
# nullVotesPercentage          0.509398
# votersPercentage            -1.158029
# subscribedVoters             0.141035
# totalVoters                  0.153941
# pre.blankVotes               0.213706
# pre.blankVotesPercentage     0.021609
# pre.nullVotes                0.091053
# pre.nullVotesPercentage      0.760916
# pre.votersPercentage        -0.779289
# pre.subscribedVoters         0.108684
# pre.totalVoters              0.128062
# Party                       -0.083536
# Mandates                    11.776208
# Percentage                   2.379792
# validVotesPercentage         2.380735
# Votes                        0.660408
# Hondt                        5.726283
# ...

# %%
#Splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=.20, random_state=42, stratify=y)

# %%
#checking the shape

print(x_train.shape, '\t\t', x_test.shape)
# Out:
# (14544, 25) 		 (3637, 25)

# %%
#Checking the shape

print(y_train.shape, '\t\t', y_test.shape)
# Out:
# (14544, 1) 		 (3637, 1)

# %%
#importing library

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

#Importing error Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#Using algorithms via for loop

model=[LinearRegression(), RandomForestRegressor(), DecisionTreeRegressor(), KNeighborsRegressor(), SVR(), Lasso(), Ridge(), ElasticNet()]
for m in model:
    m.fit(x_train, y_train)
    print('Score of', m, 'is: ', m.score(x_train, y_train))
    predm=m.predict(x_test)
    print('\n')
    print('Error:')
    print('Mean absolute error:', mean_absolute_error(y_test, predm))
    print('Mean squared error:', mean_squared_error(y_test, predm))
    print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, predm)))
    print('r2_score:', r2_score(y_test, predm))
    print('\n')
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is:  0.9745185398619254
#
#
# Error:
# Mean absolute error: 0.051242698338717314
# Mean squared error: 0.01963840602789933
# Root mean squared error: 0.14013709725800422
# r2_score: 0.9756017653446079
#
#
# *******************************************************************************************************
#
#
# Score of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) is:  0.9998522982320281
#
#
# Error:
# ...

# %%
#cross validating the models
from sklearn.model_selection import cross_val_score
model=[LinearRegression(), RandomForestRegressor(), DecisionTreeRegressor(), KNeighborsRegressor(), SVR(), Lasso(), Ridge(), ElasticNet()]
for m in model:
    score=cross_val_score(m, x, y, cv=5, scoring='r2')
    print('Score of', m, 'is:')
    print('\n')
    print('Score :', score)
    print('Mean Score :', score.mean())
    print('Standard deviation:', score.std())
    print('\n')
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is:
#
#
# Score : [0.89822196 0.96587099 0.98885269 0.99288898 0.99321186]
# Mean Score : 0.9678092968500882
# Standard deviation: 0.036230538554046204
#
#
# *******************************************************************************************************
#
#
# Score of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) is:
#
#
# Score : [0.89829055 0.99067153 0.99879569 0.9999996  0.99996546]
# Mean Score : 0.9775445655864956
# ...

# %% [markdown]
# # Saving the finalised Regressor model

# %%
#Using Random Forest model with best reults

from sklearn.ensemble import RandomForestRegressor
rf1=RandomForestRegressor()
rf1.fit(x_train, y_train)
print('Score:', rf1.score(x_train, y_train))
predrf=rf1.predict(x_test)
print('\n')
print('Mean absolute error:', mean_absolute_error(y_test, predrf))
print('Mean squared error:', mean_squared_error(y_test, predrf))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, predrf)))
print('\n')
print('r2_score:', r2_score(y_test, predrf))
# Out:
# Score: 0.9998385047025168
#
#
# Mean absolute error: 0.0013830079736046196
# Mean squared error: 0.0006158647236733573
# Root mean squared error: 0.024816621923085286
#
#
# r2_score: 0.999234866005784

# %%
predrf
# Out:
# array([1., 0., 0., ..., 1., 0., 1.])

# %%
# Saving the finalised Regressor model

from sklearn.externals import joblib

joblib.dump(predrf, 'predrf.Election Results.pkl')
# Out:
# ['predrf.Election Results.pkl']
